# %% [markdown]
# <a href="https://colab.research.google.com/github/noha2297/SSD_master/blob/master/SSD_Script2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/noha2297/SSD_master.git
# Out:
# Cloning into 'SSD_master'...
# remote: Enumerating objects: 12508, done.
# remote: Counting objects: 100% (12508/12508), done.
# remote: Compressing objects: 100% (6459/6459), done.
# remote: Total 12508 (delta 6070), reused 12455 (delta 6043), pack-reused 0
# Receiving objects: 100% (12508/12508), 963.55 MiB | 15.20 MiB/s, done.
# Resolving deltas: 100% (6070/6070), done.
# Checking out files: 100% (12414/12414), done.

# %%
cd /content/SSD_master/checkpoints
# Out:
# /content/SSD_master/checkpoints

# %%
# !unzip ssd_300_vgg.ckpt.zip
# Out:
# Archive:  ssd_300_vgg.ckpt.zip
#   inflating: ssd_300_vgg.ckpt.data-00000-of-00001
#   inflating: ssd_300_vgg.ckpt.index

# %%
cd /content/SSD_master
# Out:
# /content/SSD_master

# %%
ls
# Out:
# caffe_to_tensorflow.py  eval_ssd_network.py    tf_convert_data.py
# checkpoints/            inspect_checkpoint.py  tf_extended/
# COMMANDS.md             nets/                  tf_utils.py
# CVC-ClinicDB/           notebooks/             train_ssd_network.py
# datasets/               pictures/              VOCdevkit/
# demo/                   preprocessing/         voc_train_000.tfrecord
# deployment/             README.md              voc_train_001.tfrecord

# %%
# !./train_ssd_network.py
# Out:
# /bin/bash: ./train_ssd_network.py: Permission denied

# %%
# !chmod 770 train_ssd_network.py

# %%
# !chmod 770 tf_convert_data.py

# %%
# !ls -l
# Out:
# total 4564
# -rw-r--r-- 1 root root    2227 Apr  6 09:06 caffe_to_tensorflow.py
# drwxr-xr-x 2 root root    4096 Apr  6 09:06 checkpoints
# -rw-r--r-- 1 root root   12024 Apr  6 09:06 COMMANDS.md
# drwxr-xr-x 5 root root    4096 Apr  6 09:06 CVC-ClinicDB
# drwxr-xr-x 2 root root    4096 Apr  6 09:06 datasets
# drwxr-xr-x 2 root root    4096 Apr  6 09:06 demo
# drwxr-xr-x 2 root root    4096 Apr  6 09:06 deployment
# -rw-r--r-- 1 root root   16002 Apr  6 09:06 eval_ssd_network.py
# -rw-r--r-- 1 root root    4972 Apr  6 09:06 inspect_checkpoint.py
# drwxr-xr-x 2 root root    4096 Apr  6 09:06 nets
# drwxr-xr-x 2 root root    4096 Apr  6 09:06 notebooks
# drwxr-xr-x 2 root root    4096 Apr  6 09:06 pictures
# drwxr-xr-x 2 root root    4096 Apr  6 09:06 preprocessing
# -rw-r--r-- 1 root root    9293 Apr  6 09:06 README.md
# -rwxrwx--- 1 root root    2001 Apr  6 09:06 tf_convert_data.py
# drwxr-xr-x 2 root root    4096 Apr  6 09:06 tf_extended
# ...

# %%
# !./train_ssd_network.py
# Out:
# ./train_ssd_network.py: line 15: Generic training script that trains a SSD model using a given dataset.: command not found
# ./train_ssd_network.py: line 16: import: command not found
# from: can't read /var/mail/tensorflow.python.ops
# from: can't read /var/mail/datasets
# from: can't read /var/mail/deployment
# from: can't read /var/mail/nets
# from: can't read /var/mail/preprocessing
# ./train_ssd_network.py: line 23: import: command not found
# ./train_ssd_network.py: line 25: slim: command not found
# ./train_ssd_network.py: line 28: DATA_FORMAT: command not found
# ./train_ssd_network.py: line 33: syntax error near unexpected token `newline'
# ./train_ssd_network.py: line 33: `tf.app.flags.DEFINE_float('

# %%
# !cat train_ssd_network.py
# Out:
# # Copyright 2016 Paul Balanca. All Rights Reserved.
# #
# # Licensed under the Apache License, Version 2.0 (the "License");
# # you may not use this file except in compliance with the License.
# # You may obtain a copy of the License at
# #
# # http://www.apache.org/licenses/LICENSE-2.0
# #
# # Unless required by applicable law or agreed to in writing, software
# # distributed under the License is distributed on an "AS IS" BASIS,
# # WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# # See the License for the specific language governing permissions and
# # limitations under the License.
# # ==============================================================================
# """Generic training script that trains a SSD model using a given dataset."""
# import tensorflow as tf
# from tensorflow.python.ops import control_flow_ops
#
# from datasets import dataset_factory
# from deployment import model_deploy
# from nets import nets_factory
# ...

# %%
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-15-3e53bd3f3a21>:187: create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.create_global_step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#
# # =========================================================================== #
# ...
